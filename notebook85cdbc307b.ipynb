# %%
import warnings
warnings.filterwarnings("ignore")

import torch
import numpy as np
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_curve
)
from sklearn.preprocessing import label_binarize

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

from gensim.models import Word2Vec

from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    Trainer,
    TrainingArguments
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using Device:", device)
# Out:
# Using Device: cuda

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/deviprasaadreddy/x-dataset/Twitter_Data.csv
# /kaggle/input/datasets/deviprasaadreddy/x-dataset/Reddit_Data.csv

# %%
# Load correctly (DO NOT swap)
twitter_df = pd.read_csv("/kaggle/input/datasets/deviprasaadreddy/x-dataset/Twitter_Data.csv")
reddit_df = pd.read_csv("/kaggle/input/datasets/deviprasaadreddy/x-dataset/Reddit_Data.csv")

# Check columns first
print("Twitter Columns:", twitter_df.columns)
print("Reddit Columns:", reddit_df.columns)

# Rename correctly
twitter_df = twitter_df.rename(columns={
    "clean_text": "text",
    "category": "label"
})

reddit_df = reddit_df.rename(columns={
    "clean_comment": "text",
    "category": "label"
})

# Select only needed columns
twitter_df = twitter_df[["text", "label"]]
reddit_df = reddit_df[["text", "label"]]

# Merge
df = pd.concat([twitter_df, reddit_df], ignore_index=True)

df.dropna(inplace=True)

print("Final Columns:", df.columns)
print("Dataset Shape:", df.shape)
# Out:
# Twitter Columns: Index(['clean_text', 'category'], dtype='object')
# Reddit Columns: Index(['clean_comment', 'category'], dtype='object')
# Final Columns: Index(['text', 'label'], dtype='object')
# Dataset Shape: (200118, 2)

# %%
label_map = {-1:0, 0:1, 1:2}
df['bert_label'] = df['label'].map(label_map)

train_texts, test_texts, train_labels, test_labels = train_test_split(
    df['text'],
    df['bert_label'],
    test_size=0.2,
    stratify=df['bert_label'],
    random_state=42
)

# %%
ml_results = []

bow = CountVectorizer(max_features=10000)
X_train_bow = bow.fit_transform(train_texts)
X_test_bow = bow.transform(test_texts)

ml_models = {
    "Naive Bayes": MultinomialNB(),
    "Logistic Regression": LogisticRegression(max_iter=2000),
    "Linear SVM": LinearSVC(),
    "Random Forest": RandomForestClassifier(n_estimators=200),
    "SGD Classifier": SGDClassifier(loss="log_loss")
}

for name, model in ml_models.items():
    start = time.time()
    model.fit(X_train_bow, train_labels)
    preds = model.predict(X_test_bow)
    end = time.time()

    ml_results.append({
        "Model": name,
        "Accuracy": accuracy_score(test_labels, preds),
        "Precision": precision_score(test_labels, preds, average="weighted"),
        "Recall": recall_score(test_labels, preds, average="weighted"),
        "F1": f1_score(test_labels, preds, average="weighted"),
        "Training Time": round(end-start,2)
    })

print(pd.DataFrame(ml_results))
# Out:
#                  Model  Accuracy  Precision    Recall        F1  Training Time
# 0          Naive Bayes  0.795348   0.799398  0.795348  0.795185           0.04
# 1  Logistic Regression  0.949205   0.948979  0.949205  0.949058          41.32
# 2           Linear SVM  0.952828   0.952726  0.952828  0.952771         114.20
# 3        Random Forest  0.851864   0.857643  0.851864  0.845385        1256.22
# 4       SGD Classifier  0.904557   0.906564  0.904557  0.903073           1.12

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

train_encodings = tokenizer(
    train_texts.tolist(),
    truncation=True,
    padding=True,
    max_length=256
)

test_encodings = tokenizer(
    test_texts.tolist(),
    truncation=True,
    padding=True,
    max_length=256
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
class SentimentDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels.tolist()

    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k,v in self.encodings.items()}
        item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = SentimentDataset(train_encodings, train_labels)
test_dataset = SentimentDataset(test_encodings, test_labels)

# %%
full_model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=3
)

def model_summary(model, name):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n{name}")
    print("Total Parameters:", total)
    print("Trainable Parameters:", trainable)
    print("Non-Trainable:", total - trainable)

model_summary(full_model, "FULL BERT (12 Layers)")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# FULL BERT (12 Layers)
# Total Parameters: 109484547
# Trainable Parameters: 109484547
# Non-Trainable: 0

# %%
reduced_model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=3
)

# Reduce layers
reduced_model.bert.encoder.layer = torch.nn.ModuleList(
    reduced_model.bert.encoder.layer[:6]
)

# Freeze first 2 layers
for layer in reduced_model.bert.encoder.layer[:2]:
    for param in layer.parameters():
        param.requires_grad = False

model_summary(reduced_model, "REDUCED BERT (6 Layers, 2 Frozen)")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# REDUCED BERT (6 Layers, 2 Frozen)
# Total Parameters: 66957315
# Trainable Parameters: 52781571
# Non-Trainable: 14175744

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "precision": precision_score(labels, preds, average="weighted"),
        "recall": recall_score(labels, preds, average="weighted"),
        "f1": f1_score(labels, preds, average="weighted"),
    }

training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",   # Kaggle compatible
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=4,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    fp16=True,
    report_to="none"
)

trainer = Trainer(
    model=reduced_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='20012' max='20012' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20012/20012 2:20:26, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.258029</td>
#       <td>0.224653</td>
#       <td>0.964421</td>
#       <td>0.965315</td>
#       <td>0.964421</td>
#       <td>0.964675</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.168167</td>
#       <td>0.189768</td>
#       <td>0.973641</td>
#       <td>0.973806</td>
#       <td>0.973641</td>
#       <td>0.973562</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.121017</td>
#       <td>0.182000</td>
#       <td>0.977039</td>
#       <td>0.977116</td>
#       <td>0.977039</td>
#       <td>0.977000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.091122</td>
#       <td>0.189645</td>
#       <td>0.978763</td>
#       <td>0.978884</td>
#       <td>0.978763</td>
#       <td>0.978805</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['bert.embeddings.LayerNorm.weight', 'bert.embeddings.LayerNorm.bias', 'bert.encoder.layer.0.attention.output.LayerNorm.weight', 'bert.encoder.layer.0.attention.output.LayerNorm.bias', 'bert.encoder.layer.0.output.LayerNorm.weight', 'bert.encoder.layer.0.output.LayerNorm.bias', 'bert.encoder.layer.1.attention.output.LayerNorm.weight', 'bert.encoder.layer.1.attention.output.LayerNorm.bias', 'bert.encoder.layer.1.output.LayerNorm.weight', 'bert.encoder.layer.1.output.LayerNorm.bias', 'bert.encoder.layer.2.attention.output.LayerNorm.weight', 'bert.encoder.layer.2.attention.output.LayerNorm.bias', 'bert.encoder.layer.2.output.LayerNorm.weight', 'bert.encoder.layer.2.output.LayerNorm.bias', 'bert.encoder.layer.3.attention.output.LayerNorm.weight', 'bert.encoder.layer.3.attention.output.LayerNorm.bias', 'bert.encoder.layer.3.output.LayerNorm.weight', 'bert.encoder.layer.3.output.LayerNorm.bias', 'bert.encoder.layer.4.attention.output.LayerNorm.weight', 'bert.encoder.layer.4.attention.output.LayerNorm.bias', 'bert.encoder.layer.4.output.LayerNorm.weight', 'bert.encoder.layer.4.output.LayerNorm.bias', 'bert.encoder.layer.5.attention.output.LayerNorm.weight', 'bert.encoder.layer.5.attention.output.LayerNorm.bias', 'bert.encoder.layer.5.output.LayerNorm.weight', 'bert.encoder.layer.5.output.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['bert.embeddings.LayerNorm.beta', 'bert.embeddings.LayerNorm.gamma', 'bert.encoder.layer.0.attention.output.LayerNorm.beta', 'bert.encoder.layer.0.attention.output.LayerNorm.gamma', 'bert.encoder.layer.0.output.LayerNorm.beta', 'bert.encoder.layer.0.output.LayerNorm.gamma', 'bert.encoder.layer.1.attention.output.LayerNorm.beta', 'bert.encoder.layer.1.attention.output.LayerNorm.gamma', 'bert.encoder.layer.1.output.LayerNorm.beta', 'bert.encoder.layer.1.output.LayerNorm.gamma', 'bert.encoder.layer.2.attention.output.LayerNorm.beta', 'bert.encoder.layer.2.attention.output.LayerNorm.gamma', 'bert.encoder.layer.2.output.LayerNorm.beta', 'bert.encoder.layer.2.output.LayerNorm.gamma', 'bert.encoder.layer.3.attention.output.LayerNorm.beta', 'bert.encoder.layer.3.attention.output.LayerNorm.gamma', 'bert.encoder.layer.3.output.LayerNorm.beta', 'bert.encoder.layer.3.output.LayerNorm.gamma', 'bert.encoder.layer.4.attention.output.LayerNorm.beta', 'bert.encoder.layer.4.attention.output.LayerNorm.gamma', 'bert.encoder.layer.4.output.LayerNorm.beta', 'bert.encoder.layer.4.output.LayerNorm.gamma', 'bert.encoder.layer.5.attention.output.LayerNorm.beta', 'bert.encoder.layer.5.attention.output.LayerNorm.gamma', 'bert.encoder.layer.5.output.LayerNorm.beta', 'bert.encoder.layer.5.output.LayerNorm.gamma'].
# TrainOutput(global_step=20012, training_loss=0.22951631594390456, metrics={'train_runtime': 8428.4876, 'train_samples_per_second': 75.978, 'train_steps_per_second': 2.374, 'total_flos': 4.241522784275251e+16, 'train_loss': 0.22951631594390456, 'epoch': 4.0})

# %%
preds = trainer.predict(test_dataset)
bert_preds = np.argmax(preds.predictions, axis=1)

print("\nOVERALL METRICS")
print("Accuracy:", accuracy_score(test_labels, bert_preds))
print("Precision:", precision_score(test_labels, bert_preds, average="weighted"))
print("Recall:", recall_score(test_labels, bert_preds, average="weighted"))
print("F1 Score:", f1_score(test_labels, bert_preds, average="weighted"))
# Out:
# OVERALL METRICS
# Accuracy: 0.9787627423545873
# Precision: 0.9788838903596968
# Recall: 0.9787627423545873
# F1 Score: 0.9788050707193492

# %%
print("\nPER CLASS METRICS")
print(classification_report(
    test_labels,
    bert_preds,
    target_names=["Negative","Neutral","Positive"]
))
# Out:
# PER CLASS METRICS
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.97      0.96      8757
#      Neutral       0.99      0.98      0.99     13651
#     Positive       0.98      0.98      0.98     17616
#
#     accuracy                           0.98     40024
#    macro avg       0.98      0.98      0.98     40024
# weighted avg       0.98      0.98      0.98     40024

# %%
# Compute confusion matrix
cm = confusion_matrix(test_labels, bert_preds)

plt.figure(figsize=(6,5))
sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Blues",
            xticklabels=["Negative","Neutral","Positive"],
            yticklabels=["Negative","Neutral","Positive"])

plt.title("Confusion Matrix - Sentiment Classification")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
from sklearn.metrics import classification_report
import pandas as pd

# Get classification report as dictionary
report = classification_report(
    test_labels,
    bert_preds,
    target_names=["Negative","Neutral","Positive"],
    output_dict=True
)

report_df = pd.DataFrame(report).transpose()

# Select only class rows
class_metrics = report_df.loc[["Negative","Neutral","Positive"], 
                              ["precision","recall","f1-score"]]

# Plot
class_metrics.plot(kind="bar", figsize=(8,5))
plt.title("Per-Class Precision, Recall, F1-Score")
plt.ylabel("Score")
plt.ylim(0,1)
plt.xticks(rotation=0)
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import numpy as np
import torch

# Convert labels to binary format
y_bin = label_binarize(test_labels, classes=[0,1,2])

# Convert logits to probabilities
probs = torch.nn.functional.softmax(
    torch.tensor(preds.predictions), dim=1
).numpy()

plt.figure(figsize=(6,5))

for i, label in enumerate(["Negative","Neutral","Positive"]):
    fpr, tpr, _ = roc_curve(y_bin[:, i], probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{label} (AUC = {roc_auc:.3f})")

plt.plot([0,1],[0,1],'k--')
plt.title("ROC Curve (One-vs-Rest)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Convert labels to binary format
y_bin = label_binarize(test_labels, classes=[0,1,2])

# Convert logits to probabilities
probs = torch.nn.functional.softmax(
    torch.tensor(preds.predictions), dim=1
).numpy()

plt.figure(figsize=(6,5))

for i, label in enumerate(["Negative","Neutral","Positive"]):
    fpr, tpr, _ = roc_curve(y_bin[:, i], probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{label} (AUC = {roc_auc:.3f})")

plt.plot([0,1],[0,1],'k--')
plt.title("ROC Curve (One-vs-Rest)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

df["bert_label"].value_counts().sort_index().plot(
    kind="bar",
    color=["red","gold","green"]
)

plt.xticks([0,1,2], ["Negative","Neutral","Positive"], rotation=0)
plt.title("Class Distribution")
plt.ylabel("Number of Samples")
plt.show()

# %%
reduced_model.config.output_hidden_states = True
reduced_model.to(device)

sample = test_dataset[0]
sample = {k: v.unsqueeze(0).to(device) for k,v in sample.items()}

outputs = reduced_model(**sample)

hidden_states = outputs.hidden_states

print("\nNumber of Transformer Layers:", len(hidden_states))

for i, layer in enumerate(hidden_states):
    print(f"Layer {i} shape:", layer.shape)
# Out:
# Number of Transformer Layers: 7
# Layer 0 shape: torch.Size([1, 256, 768])
# Layer 1 shape: torch.Size([1, 256, 768])
# Layer 2 shape: torch.Size([1, 256, 768])
# Layer 3 shape: torch.Size([1, 256, 768])
# Layer 4 shape: torch.Size([1, 256, 768])
# Layer 5 shape: torch.Size([1, 256, 768])
# Layer 6 shape: torch.Size([1, 256, 768])

# %%
import pandas as pd

summary_data = []

for name, model in [
    ("Full BERT", full_model),
    ("Reduced BERT", reduced_model)
]:
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

    summary_data.append({
        "Model": name,
        "Total Params": total,
        "Trainable Params": trainable,
        "Non-Trainable Params": total - trainable
    })

summary_df = pd.DataFrame(summary_data)
print(summary_df)
# Out:
#           Model  Total Params  Trainable Params  Non-Trainable Params
# 0     Full BERT     109484547         109484547                     0
# 1  Reduced BERT      66957315          52781571              14175744

# %%
print("\n===== PARAMETER NAMES IN EACH MODEL =====\n")

for name, model in [
    ("Full BERT", full_model),
    ("Reduced BERT", reduced_model)
]:
    print(f"\n--- {name} ---\n")
    
    for param_name, param in model.named_parameters():
        print(f"{param_name} → Shape: {param.shape}")
# Out:
# ===== PARAMETER NAMES IN EACH MODEL =====
#
#
# --- Full BERT ---
#
# bert.embeddings.word_embeddings.weight → Shape: torch.Size([30522, 768])
# bert.embeddings.position_embeddings.weight → Shape: torch.Size([512, 768])
# bert.embeddings.token_type_embeddings.weight → Shape: torch.Size([2, 768])
# bert.embeddings.LayerNorm.weight → Shape: torch.Size([768])
# bert.embeddings.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.0.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.0.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.0.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.0.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.1.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.1.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.1.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.1.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.2.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.2.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.2.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.2.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.3.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.3.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.3.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.3.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.4.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.4.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.4.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.4.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.5.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.5.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.5.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.5.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.6.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.6.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.6.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.6.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.6.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.6.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.6.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.6.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.6.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.6.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.7.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.7.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.7.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.7.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.7.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.7.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.7.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.7.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.7.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.7.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.8.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.8.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.8.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.8.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.8.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.8.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.8.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.8.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.8.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.8.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.9.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.9.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.9.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.9.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.9.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.9.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.9.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.9.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.9.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.9.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.10.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.10.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.10.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.10.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.10.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.10.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.10.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.10.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.10.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.10.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.11.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.11.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.11.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.11.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.11.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.11.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.11.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.11.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.11.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.11.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.pooler.dense.weight → Shape: torch.Size([768, 768])
# bert.pooler.dense.bias → Shape: torch.Size([768])
# classifier.weight → Shape: torch.Size([3, 768])
# classifier.bias → Shape: torch.Size([3])
#
# --- Reduced BERT ---
#
# bert.embeddings.word_embeddings.weight → Shape: torch.Size([30522, 768])
# bert.embeddings.position_embeddings.weight → Shape: torch.Size([512, 768])
# bert.embeddings.token_type_embeddings.weight → Shape: torch.Size([2, 768])
# bert.embeddings.LayerNorm.weight → Shape: torch.Size([768])
# bert.embeddings.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.0.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.0.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.0.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.0.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.0.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.0.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.0.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.1.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.1.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.1.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.1.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.1.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.1.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.1.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.2.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.2.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.2.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.2.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.2.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.2.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.2.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.3.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.3.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.3.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.3.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.3.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.3.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.3.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.4.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.4.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.4.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.4.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.4.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.4.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.4.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.self.query.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.query.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.self.key.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.key.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.self.value.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.value.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.output.dense.weight → Shape: torch.Size([768, 768])
# bert.encoder.layer.5.attention.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.5.attention.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.intermediate.dense.weight → Shape: torch.Size([3072, 768])
# bert.encoder.layer.5.intermediate.dense.bias → Shape: torch.Size([3072])
# bert.encoder.layer.5.output.dense.weight → Shape: torch.Size([768, 3072])
# bert.encoder.layer.5.output.dense.bias → Shape: torch.Size([768])
# bert.encoder.layer.5.output.LayerNorm.weight → Shape: torch.Size([768])
# bert.encoder.layer.5.output.LayerNorm.bias → Shape: torch.Size([768])
# bert.pooler.dense.weight → Shape: torch.Size([768, 768])
# bert.pooler.dense.bias → Shape: torch.Size([768])
# classifier.weight → Shape: torch.Size([3, 768])
# classifier.bias → Shape: torch.Size([3])

# %%
# Get parameter names from full model
full_param_names = set(name for name, _ in full_model.named_parameters())

# Get parameter names from reduced model
reduced_param_names = set(name for name, _ in reduced_model.named_parameters())

# %%
# Parameters removed entirely
removed_params = full_param_names - reduced_param_names

print("\n===== PARAMETERS REMOVED COMPLETELY =====\n")

for name in sorted(removed_params):
    print(name)
# Out:
# ===== PARAMETERS REMOVED COMPLETELY =====
#
# bert.encoder.layer.10.attention.output.LayerNorm.bias
# bert.encoder.layer.10.attention.output.LayerNorm.weight
# bert.encoder.layer.10.attention.output.dense.bias
# bert.encoder.layer.10.attention.output.dense.weight
# bert.encoder.layer.10.attention.self.key.bias
# bert.encoder.layer.10.attention.self.key.weight
# bert.encoder.layer.10.attention.self.query.bias
# bert.encoder.layer.10.attention.self.query.weight
# bert.encoder.layer.10.attention.self.value.bias
# bert.encoder.layer.10.attention.self.value.weight
# bert.encoder.layer.10.intermediate.dense.bias
# bert.encoder.layer.10.intermediate.dense.weight
# bert.encoder.layer.10.output.LayerNorm.bias
# bert.encoder.layer.10.output.LayerNorm.weight
# bert.encoder.layer.10.output.dense.bias
# bert.encoder.layer.10.output.dense.weight
# bert.encoder.layer.11.attention.output.LayerNorm.bias
# bert.encoder.layer.11.attention.output.LayerNorm.weight
# bert.encoder.layer.11.attention.output.dense.bias
# bert.encoder.layer.11.attention.output.dense.weight
# bert.encoder.layer.11.attention.self.key.bias
# bert.encoder.layer.11.attention.self.key.weight
# bert.encoder.layer.11.attention.self.query.bias
# bert.encoder.layer.11.attention.self.query.weight
# bert.encoder.layer.11.attention.self.value.bias
# bert.encoder.layer.11.attention.self.value.weight
# bert.encoder.layer.11.intermediate.dense.bias
# bert.encoder.layer.11.intermediate.dense.weight
# bert.encoder.layer.11.output.LayerNorm.bias
# bert.encoder.layer.11.output.LayerNorm.weight
# bert.encoder.layer.11.output.dense.bias
# bert.encoder.layer.11.output.dense.weight
# bert.encoder.layer.6.attention.output.LayerNorm.bias
# bert.encoder.layer.6.attention.output.LayerNorm.weight
# bert.encoder.layer.6.attention.output.dense.bias
# bert.encoder.layer.6.attention.output.dense.weight
# bert.encoder.layer.6.attention.self.key.bias
# bert.encoder.layer.6.attention.self.key.weight
# bert.encoder.layer.6.attention.self.query.bias
# bert.encoder.layer.6.attention.self.query.weight
# bert.encoder.layer.6.attention.self.value.bias
# bert.encoder.layer.6.attention.self.value.weight
# bert.encoder.layer.6.intermediate.dense.bias
# bert.encoder.layer.6.intermediate.dense.weight
# bert.encoder.layer.6.output.LayerNorm.bias
# bert.encoder.layer.6.output.LayerNorm.weight
# bert.encoder.layer.6.output.dense.bias
# bert.encoder.layer.6.output.dense.weight
# bert.encoder.layer.7.attention.output.LayerNorm.bias
# bert.encoder.layer.7.attention.output.LayerNorm.weight
# bert.encoder.layer.7.attention.output.dense.bias
# bert.encoder.layer.7.attention.output.dense.weight
# bert.encoder.layer.7.attention.self.key.bias
# bert.encoder.layer.7.attention.self.key.weight
# bert.encoder.layer.7.attention.self.query.bias
# bert.encoder.layer.7.attention.self.query.weight
# bert.encoder.layer.7.attention.self.value.bias
# bert.encoder.layer.7.attention.self.value.weight
# bert.encoder.layer.7.intermediate.dense.bias
# bert.encoder.layer.7.intermediate.dense.weight
# bert.encoder.layer.7.output.LayerNorm.bias
# bert.encoder.layer.7.output.LayerNorm.weight
# bert.encoder.layer.7.output.dense.bias
# bert.encoder.layer.7.output.dense.weight
# bert.encoder.layer.8.attention.output.LayerNorm.bias
# bert.encoder.layer.8.attention.output.LayerNorm.weight
# bert.encoder.layer.8.attention.output.dense.bias
# bert.encoder.layer.8.attention.output.dense.weight
# bert.encoder.layer.8.attention.self.key.bias
# bert.encoder.layer.8.attention.self.key.weight
# bert.encoder.layer.8.attention.self.query.bias
# bert.encoder.layer.8.attention.self.query.weight
# bert.encoder.layer.8.attention.self.value.bias
# bert.encoder.layer.8.attention.self.value.weight
# bert.encoder.layer.8.intermediate.dense.bias
# bert.encoder.layer.8.intermediate.dense.weight
# bert.encoder.layer.8.output.LayerNorm.bias
# bert.encoder.layer.8.output.LayerNorm.weight
# bert.encoder.layer.8.output.dense.bias
# bert.encoder.layer.8.output.dense.weight
# bert.encoder.layer.9.attention.output.LayerNorm.bias
# bert.encoder.layer.9.attention.output.LayerNorm.weight
# bert.encoder.layer.9.attention.output.dense.bias
# bert.encoder.layer.9.attention.output.dense.weight
# bert.encoder.layer.9.attention.self.key.bias
# bert.encoder.layer.9.attention.self.key.weight
# bert.encoder.layer.9.attention.self.query.bias
# bert.encoder.layer.9.attention.self.query.weight
# bert.encoder.layer.9.attention.self.value.bias
# bert.encoder.layer.9.attention.self.value.weight
# bert.encoder.layer.9.intermediate.dense.bias
# bert.encoder.layer.9.intermediate.dense.weight
# bert.encoder.layer.9.output.LayerNorm.bias
# bert.encoder.layer.9.output.LayerNorm.weight
# bert.encoder.layer.9.output.dense.bias
# bert.encoder.layer.9.output.dense.weight

# %%
# Select layers to print
layers_to_print = [1, 2]   # Encoder Layer 1 and Encoder Layer 6

print("\n===== SELECTED LAYER FEATURE VECTORS =====")

for i in layers_to_print:
    cls_vector = hidden_states[i][0, 0, :]   # CLS token
    print(f"\nLayer {i} CLS Vector Shape:", cls_vector.shape)
    print(cls_vector.detach().cpu().numpy())
# Out:
# ===== SELECTED LAYER FEATURE VECTORS =====
#
# Layer 1 CLS Vector Shape: torch.Size([768])
# [ 2.16550395e-01  3.00932657e-02 -6.36154339e-02 -2.18886614e-01
#   1.59041584e-01  6.79469900e-03 -1.44616917e-01 -1.08302243e-01
#   3.68258692e-02 -4.89347637e-01  6.25459030e-02  5.10047860e-02
#   7.55861998e-02 -1.48052797e-01 -2.82370061e-01  3.36829394e-01
#   3.15926850e-01  2.10201159e-01 -8.79418254e-02 -4.98997957e-01
#  -5.59458196e-01 -3.37855130e-01 -1.45375311e-01 -1.02489792e-01
#  -5.39072528e-02 -3.05581540e-01 -1.86045066e-01  1.36340797e-01
#  -3.20415497e-02 -2.82301493e-02 -2.63654053e-01 -1.06608391e-01
#   2.26621613e-01  8.94831270e-02 -3.41926217e-01  1.30440846e-01
#  -2.33494014e-01  1.61064744e-01  6.35702861e-03  1.17643118e-01
#   2.32996121e-01 -2.26415306e-01  4.13246453e-02  2.44456977e-01
#  -1.03959339e-02  1.73007771e-01 -2.12491035e+00 -4.42305468e-02
#   5.23705840e-01 -2.24603415e-01  5.59676230e-01  9.92104709e-02
#  -3.87588620e-01  7.32600510e-01  2.13720873e-01 -1.24603905e-01
#  -2.61090666e-01  1.72587596e-02  2.24551246e-01 -2.38333672e-01
#  -2.34532095e-02  2.75551863e-02 -2.49060869e-01  5.56386709e-02
#  -8.45791399e-02  1.41601264e-01  2.06136648e-02 -1.02258213e-01
#  -1.20368779e-01 -2.50907615e-04  4.19561751e-02 -8.11131671e-02
#  -2.90020823e-01 -3.45560461e-01  1.51562259e-01 -2.06949726e-01
#  -2.52785027e-01  2.46040732e-01  1.31500840e-01  3.44767958e-01
#  -2.29072362e-01 -1.94994316e-01  9.76865068e-02  8.49998072e-02
#   2.60918289e-01  1.86394930e-01  2.64336348e-01  2.72684991e-01
#  -1.37314826e-01  1.64148808e-01 -3.52725089e-01 -5.68901151e-02
#  -2.38210678e-01  1.42155796e-01  1.23829037e-01 -2.87986174e-03
#   3.55284899e-01 -3.40508401e-01 -1.79150343e-01 -2.71462262e-01
#   2.48416495e-02 -2.88348079e-01  7.55689144e-02 -1.86466053e-01
#  -4.09219980e-01  2.40615875e-01  7.78048160e-03 -7.46944249e-02
#  -2.72193812e-02  5.81409074e-02  2.82999128e-01 -4.29517291e-02
#  -8.48961025e-02 -2.28087157e-01  1.52689710e-01  1.66632935e-01
#  -3.57007831e-01 -4.36376445e-02  2.80921042e-01 -1.58184782e-01
#  -1.83620512e-01  7.30263531e-01 -2.17262760e-01 -3.30005974e-01
#  -2.12029666e-02  2.81794611e-02  8.35396871e-02  6.74331188e-02
#  -1.19677268e-01  6.77507296e-02  3.53616476e-01 -4.49839421e-03
#   6.28092527e-01  5.78509979e-02  3.50649022e-02  3.54418516e-01
#   3.91420692e-01  9.60367471e-02  2.54640877e-01  2.15665436e+00
#   7.55856782e-02 -1.04891315e-01 -4.12658781e-01  2.46263251e-01
#  -2.13458017e-01 -1.88717917e-01  1.42527670e-01  1.04660049e-01
#   1.15434788e-01  9.17554200e-02 -1.62461698e-01 -1.07908145e-01
#   1.23305572e-02 -6.01194128e-02  9.97665301e-02  1.70594171e-01
#  -4.80645150e-02  5.40979020e-03 -8.12290981e-02 -1.45753652e-01
#   8.36666152e-02 -1.15001723e-01  1.02849513e-01 -1.93195224e-01
#  -2.29468748e-01  1.09234698e-01  3.54167938e-01  6.46535084e-02
#   8.11277628e-01 -2.52755105e-01 -1.04289325e-02 -1.71401948e-02
#   5.80219775e-02 -2.14434370e-01  3.06424964e-02 -2.61490077e-01
#  -9.81559418e-03 -2.68269986e-01 -1.64242774e-01  1.78967506e-01
#   1.00536913e-01  7.68515766e-02 -1.95023820e-01 -8.34804624e-02
#   7.71816522e-02 -3.55354607e-01  1.56445667e-01 -3.06261450e-01
#  -1.93172723e-01  1.35553837e-01  4.13076859e-03  5.81555963e-02
#  -3.50210696e-01  1.99945256e-01  5.08759655e-02 -7.08461106e-02
#   1.47541001e-01  1.83745220e-01 -1.51243195e-01 -1.43609807e-01
#  -2.42020860e-01 -1.03351168e-01  2.50156164e-01 -2.57180214e-01
#   1.94704384e-01 -1.79617867e-01  6.02288395e-02  1.57647729e-01
#   8.67539868e-02 -3.75477895e-02  1.28339604e-01 -1.46587878e-01
#   1.01153307e-01 -3.43325958e-02 -1.85000941e-01 -1.24893576e-01
#   1.16576701e-02  1.53855681e-01  2.36457467e-01  7.28266500e-03
#   1.91134661e-01  1.11652888e-01 -1.93930134e-01  2.18931660e-01
#  -4.66011800e-02  3.97769123e-01  2.23431736e-01  3.72335494e-01
#  -1.54027119e-01 -4.61084783e-01  6.39568493e-02 -6.06883802e-02
#   1.29098326e-01  5.98680973e-02 -5.96018583e-02  2.61390537e-01
#  -7.24938959e-02 -1.87438324e-01 -3.08553070e-01 -7.48593882e-02
#  -7.91192204e-02 -1.81180373e-01  2.17494473e-01 -2.67956089e-02
#  -5.26082590e-02 -5.99069715e-01  1.08558893e-01  5.25429584e-02
#   1.84672192e-01  3.49205464e-01 -1.42353207e-01 -3.46094370e-01
#   2.32142881e-01  1.83996513e-01  3.11306156e-02  6.97101131e-02
#   2.19026282e-01  1.55540407e-01  3.15579362e-02 -3.23633887e-02
#  -3.44653308e-01  4.17561531e-02  7.94711784e-02 -7.10053295e-02
#  -7.99020901e-02 -3.12934101e-01 -1.66417196e-01 -2.97431983e-02
#   1.27960429e-01 -1.44697363e-02 -4.58994731e-02  3.28256041e-01
#   6.51043802e-02  1.57396227e-01 -4.29914802e-01 -2.78451115e-01
#   4.44810232e-03  3.02633226e-01  6.24575689e-02 -8.12735930e-02
#   3.05337925e-02 -1.37533741e-02  4.92170528e-02 -2.58686602e-01
#   2.01580375e-01  2.93280870e-01 -1.95869822e-02 -1.41599819e-01
#   4.51215804e-02 -8.68879631e-02  5.80330119e-02 -1.33769229e-01
#   9.81702656e-02  2.24923976e-02  7.49133676e-02  9.81095582e-02
#   3.92286330e-01 -2.04025805e-01 -2.03145072e-01 -3.82813036e-01
#  -2.31257111e-01  2.84578830e-01  3.88116002e-01 -2.48241931e-01
#  -1.00432837e+00 -1.14437237e-01 -4.88259554e-01 -3.84869613e-02
#  -1.00078650e+01 -1.63683817e-01 -3.82353514e-01  1.79201946e-01
#   3.76173735e-01 -1.57533381e-02  1.38459317e-02 -1.02841347e-01
#  -2.54526556e-01 -4.45171073e-02  2.02780053e-01  6.33907318e-01
#   1.01926051e-01  2.03335270e-01  2.03596532e-01 -1.25143826e-02
#  -1.19480319e-01 -1.70841917e-01  3.08405887e-02 -1.75208300e-01
#   1.67553186e-01  1.22331351e-01  2.36824349e-01 -9.34868827e-02
#   4.16332811e-01 -2.93367100e-03 -6.01079941e-01 -1.26325451e-02
#   1.42430559e-01 -4.39896226e-01  1.88147232e-01 -1.68652982e-01
#  -1.11689888e-01 -4.79488410e-02  2.12722570e-01  2.07789857e-02
#   2.03635231e-01  4.78582233e-01  1.05978802e-01  9.59337875e-02
#   8.95165429e-02 -3.44467908e-02 -2.86109746e-01  7.16228038e-02
#   7.61529580e-02  5.62350675e-02 -3.07414643e-02  7.22092614e-02
#  -3.46657187e-01  1.71582967e-01  8.86681024e-03  7.69670233e-02
#   6.61149174e-02  2.60928959e-01  3.04059163e-02 -2.22197056e-01
#  -2.71017384e-02 -1.96238384e-01  1.88001096e-01 -3.63061912e-02
#  -2.79863209e-01 -2.64844865e-01  1.77662298e-01 -3.55925977e-01
#   2.99753517e-01 -1.08191311e-01 -3.68884727e-02 -3.06209326e-01
#  -4.88131285e-01  2.79176515e-02 -6.56181574e-02 -1.77491978e-01
#   7.40793208e-03 -1.13286853e+00 -8.30662698e-02 -1.92601323e-01
#   2.11188868e-01 -5.57202511e-02 -1.50546849e-01  1.75245970e-01
#  -2.68790334e-01  2.12212175e-01 -5.22244275e-02 -7.20686391e-02
#  -6.98007122e-02 -1.74148872e-01 -4.49725807e-01 -3.37199330e-01
#  -2.79908776e-01 -7.08347708e-02  1.59600645e-01 -6.64985403e-02
#  -1.36691630e-01  3.41328979e-01 -1.71852931e-01 -7.03144521e-02
#  -2.22946033e-02 -3.05195361e-01 -2.03741223e-01  4.61484864e-02
#  -2.45528314e-02  1.18099628e-02  2.61579096e-01 -6.06769919e-02
#  -8.37662369e-02 -1.91573545e-01  2.20139891e-01  2.95619756e-01
#  -9.56192464e-02  4.78281006e-02 -8.24099481e-02  3.23189527e-01
#   4.62563246e-01  1.12791777e-01  1.77464351e-01 -1.10160775e-01
#  -1.54971585e-01  7.41244154e-03  1.71039522e-01 -1.32509515e-01
#  -1.99811146e-01 -1.13057077e-01 -6.28154799e-02  6.35501295e-02
#  -1.59540609e-01 -2.28355899e-02 -1.51916564e-01 -1.94600165e-01
#   3.21890377e-02  1.65871438e-02  3.94204617e-01  2.17046469e-01
#   2.95120515e-02  2.19875753e-01 -8.60344172e-02  8.77856433e-01
#   1.49518475e-01 -2.68301338e-01 -3.52145404e-01  5.00360072e-01
#   2.71707505e-01  3.10179312e-02 -8.34003836e-02  7.37400651e-02
#  -1.44648761e-01  3.51454586e-01 -4.32083048e-02  1.34630010e-01
#   3.69467363e-02  5.24433143e-02  9.68958531e-03  1.49876595e-01
#   1.69447020e-01  2.71889299e-01 -1.34852648e-01  1.58252306e-02
#  -4.40281421e-01  1.68363005e-01  2.14369476e-01 -2.55384684e-01
#   3.33278149e-01  7.47966021e-02 -8.10484231e-01  5.24511524e-02
#   1.70506194e-01  3.59185971e-02 -1.34000018e-01 -1.63539201e-01
#   4.72946823e-01  1.09209985e-01  3.72756124e-02 -9.26414952e-02
#   4.13230181e-01  3.46277893e-01 -4.01775062e-01  6.67044744e-02
#  -1.03730999e-01  8.61671120e-02  1.76115945e-01  3.16981673e-02
#   8.17340519e-03  1.97237924e-01  7.20781554e-03  3.62595946e-01
#   1.38144866e-01  1.47789612e-01  4.51089591e-01  9.55229104e-02
#   3.60086322e-01  3.47001731e-01  2.16383953e-02 -3.08907092e-01
#   2.69871522e-02 -1.61190525e-01 -8.92431103e-03 -4.85328853e-01
#  -9.92386863e-02 -9.80949327e-02 -2.20194697e-01 -1.02591857e-01
#   4.84788083e-02 -4.02135044e-01  1.21735092e-02  9.86130014e-02
#  -4.69172090e-01 -1.93073779e-01  6.01480268e-02 -9.90104750e-02
#   3.10180243e-02  2.90757269e-01  3.91311049e-02  3.93233955e-01
#  -1.51582540e-03 -4.50863969e-03  4.58784729e-01  2.44749352e-01
#   7.39591047e-02  9.79281738e-02 -1.57239839e-01 -1.75562412e-01
#  -2.43945733e-01  1.47741675e-01  5.12387380e-02 -3.77133518e-01
#  -3.09026331e-01  1.35294452e-01  1.04279831e-01 -2.81712323e-01
#   1.00345425e-01  1.29527096e-02 -8.65972019e-04 -5.23026347e-01
#  -1.47936642e-01  3.30822378e-01 -1.08687386e-01  2.51025140e-01
#  -8.06251988e-02  7.44340003e-01 -1.05007850e-01 -2.03703903e-03
#  -4.54589546e-01 -1.23673446e-01 -3.15633923e-01 -2.62914568e-01
#  -8.42818767e-02  3.97947393e-02  1.05509855e-01  5.41147515e-02
#  -1.23282775e-01 -3.63145471e-02  1.05094396e-01  1.33789957e-01
#  -3.51297110e-01  3.54360700e-01  3.59828591e-01 -6.98933378e-02
#   1.09299287e-01 -2.87937522e-01 -1.53059155e-01 -2.63124079e-01
#   2.27356151e-01  3.87583673e-03 -5.80072030e-02  1.48984849e-01
#  -1.62189286e-02  3.66636664e-01  1.46371961e-01  3.06345373e-01
#   1.08513787e-01 -6.47924542e-02  1.41505584e-01 -3.38804483e-01
#   2.44963430e-02  3.25728357e-01 -2.17904106e-01  2.30860170e-02
#   7.51162693e-02 -1.04517594e-01 -3.39550823e-01 -6.28228188e-02
#   2.28711292e-01  1.12514444e-01 -1.82108060e-01  1.71773419e-01
#  -8.61924663e-02 -1.38828635e-01  7.87539110e-02 -7.00274557e-02
#   1.49780855e-01 -6.88834265e-02  2.74970364e-02  1.52300566e-01
#  -3.03673774e-01 -1.86159387e-01  2.26653945e-02  2.88683921e-01
#   7.45077431e-02 -3.59565243e-02 -3.60570669e-01  8.88456702e-02
#  -3.08163106e-01  2.49004528e-01 -3.41249913e-01 -4.18670952e-01
#  -1.28678828e-01  2.39192322e-02 -3.66937459e-01 -3.59085828e-01
#   1.35824770e-01  7.47143552e-02 -1.33480653e-02  1.05808508e-02
#  -6.55754358e-02  3.12858731e-01 -1.30964205e-01  1.17924199e-01
#  -2.89691314e-02  1.17903471e-01  1.35329276e-01 -5.07133044e-02
#   6.44480437e-02  4.41542640e-02  3.29061821e-02 -2.66125709e-01
#  -1.50038227e-01  2.71267831e-01  3.27849120e-01  9.42009613e-02
#   1.86863393e-01  1.70911774e-01  1.67191122e-02  3.94764170e-02
#   4.95472662e-02  5.11780083e-02 -5.21891974e-02 -1.01693399e-01
#   2.10667968e-01  4.82020289e-01 -3.38911176e-01 -6.84360713e-02
#  -3.09504047e-02 -3.06146150e-03  1.68654665e-01 -1.13772452e-02
#   3.10607344e-01  1.45833656e-01  3.80826159e-03  4.55007330e-02
#   7.19657913e-02 -2.36287013e-01  2.78843522e-01 -3.38482618e-01
#   1.92695364e-01 -7.63751119e-02 -3.56453031e-01 -3.35903287e-01
#  -9.92516726e-02  6.79642111e-02 -2.52561271e-01 -1.84211247e-02
#  -1.71987861e-01  1.94902390e-01  1.81130871e-01 -6.41745329e-02
#  -2.29643792e-01 -5.99125680e-03 -1.84802204e-01 -8.73522274e-03
#   3.93562168e-02 -5.05058058e-02  2.59138584e-01  5.18128037e-01
#  -2.81873226e-01  1.18415497e-01 -4.41988349e-01 -7.20888451e-02
#  -2.03759208e-01  3.69407088e-02 -7.37561882e-02 -5.55198267e-03
#  -9.76205915e-02 -3.37229855e-02 -1.13227874e-01 -1.92079991e-01
#   5.44936396e-02  2.95311123e-01 -3.99541199e-01  2.24846333e-01
#   3.70427072e-02 -9.50845927e-02 -9.40672755e-02 -2.34388217e-01
#  -1.53617233e-01  1.35508269e-01  1.50385899e-02 -1.90569028e-01
#   2.11231187e-01 -1.96430162e-01  5.38264334e-01  1.51305050e-01
#   1.21227212e-01  9.04304720e-03  2.17146069e-01 -4.35435213e-02
#   3.33159268e-01  2.46675342e-01 -2.06038266e-01 -2.59878095e-02
#  -3.50952148e-02  1.40665174e-01 -1.26719698e-01 -9.54303667e-02
#   3.66277918e-02  2.67896742e-01 -2.45964155e-01 -1.81449264e-01
#  -7.87143186e-02 -1.01087593e-01 -1.20257363e-01  2.36123316e-02
#   1.73685148e-01  8.52306336e-02 -1.82438925e-01  4.36480969e-01
#  -1.12792049e-02 -7.63758659e-01 -1.69922799e-01 -5.95548674e-02
#   7.63503984e-02  2.57965326e-01 -1.58130124e-01  8.24854299e-02
#  -3.50658298e-01  1.83165401e-01 -2.69231558e-01 -1.68353349e-01
#  -7.38533586e-02  1.46460578e-01  2.41596818e-01  1.24032713e-01
#   4.54909384e-01  6.27721474e-02 -1.62951052e-01 -2.96242051e-02
#  -2.07905054e-01 -6.82231784e-02 -1.41381994e-01  1.12514630e-01
#  -2.61074722e-01  1.34100497e-01  2.19610751e-01 -3.34280580e-01
#  -4.52803522e-02 -2.08703801e-01  2.27935448e-01 -2.06751332e-01
#  -1.13678895e-01  1.34705618e-01  8.11332688e-02  4.12751250e-02]
#
# Layer 2 CLS Vector Shape: torch.Size([768])
# [ 1.69119954e-01 -1.66113168e-01 -2.09587261e-01 -1.51648596e-01
#  -2.64594574e-02  1.39880963e-02 -1.97679311e-01 -5.04816324e-02
#   4.79705594e-02 -3.98304820e-01  1.53350905e-01  8.29881281e-02
#  -8.37370083e-02 -7.01586455e-02 -3.13080162e-01  1.66513667e-01
#  -1.28734216e-01  1.98997170e-01 -8.36160928e-02 -1.98928803e-01
#  -4.93678451e-01 -9.89075303e-02  1.60214361e-02 -7.85970688e-02
#   1.27914920e-01 -1.73974410e-01 -1.24501079e-01  1.42867580e-01
#   1.98478084e-02  9.28340852e-02 -1.55238077e-01  5.57516627e-02
#   1.29541129e-01  1.96918800e-01 -3.62176061e-01 -1.72559265e-02
#  -3.07307422e-01  1.81783363e-01 -1.42969359e-02  1.15700737e-01
#   6.24615103e-02 -1.54324040e-01 -5.43660820e-02  8.73792544e-02
#  -1.73891708e-02  2.64687777e-01 -2.18363857e+00  2.09538117e-02
#   4.48773831e-01 -3.26828867e-01  4.92850214e-01  5.48019744e-02
#  -4.74170417e-01  7.10991502e-01  3.50184739e-01  1.65652356e-03
#  -3.14560324e-01  7.41153657e-02  1.53191671e-01 -2.29049966e-01
#  -1.93607047e-01  1.07786529e-01 -4.77644764e-02  1.33685261e-01
#  -1.25287458e-01  1.18368901e-01  1.97620932e-02 -7.91560393e-03
#  -6.01168834e-02  1.89607069e-01  1.47345692e-01 -2.21904516e-02
#  -3.02358240e-01 -2.92614192e-01  1.51779965e-01 -1.65957630e-01
#  -1.33270413e-01  1.05651766e-01 -1.22443086e-03  2.50346363e-01
#  -2.96183199e-01 -2.72612840e-01  1.55404836e-01  2.66269706e-02
#   9.69738811e-02  3.05984944e-01  2.38875002e-01  1.92715332e-01
#   6.10415637e-03  1.91486314e-01 -5.10903299e-01 -8.44279677e-03
#  -1.92517295e-01  8.17901492e-02  6.87732548e-02  2.90696993e-02
#   2.27009267e-01 -3.73197496e-01 -9.69662145e-02 -2.92560339e-01
#   6.07824810e-02 -1.22429200e-01 -2.47115772e-02 -1.69809043e-01
#  -2.71823019e-01  2.64943182e-01 -5.39234802e-02 -2.75804460e-01
#   1.43003568e-01  1.39999941e-01  2.88355350e-01  6.27094582e-02
#  -3.20904888e-02 -2.98339397e-01  3.19332957e-01 -1.53733958e-02
#  -4.02662724e-01  3.04220244e-02  2.74335027e-01 -1.72453329e-01
#  -1.44135281e-01  6.02235138e-01 -1.60973787e-01 -2.82482356e-01
#  -2.08558500e-01 -1.16995648e-01  3.38316970e-02 -3.75582315e-02
#   5.93471760e-03  1.34300202e-01  3.43824536e-01 -1.54004514e-01
#   3.87029380e-01  9.07319132e-03 -8.54885653e-02  2.90890515e-01
#   2.93774277e-01  1.65005818e-01  1.46575034e-01  1.08506358e+00
#   6.65926561e-02 -1.31597623e-01 -4.71143335e-01  3.76465917e-01
#  -3.75245847e-02 -3.21071856e-02 -4.02549691e-02  1.01778097e-01
#   4.01072763e-02 -4.78688143e-02 -1.30423233e-01 -4.14974913e-02
#   1.64930880e-01 -8.98941830e-02  8.51466283e-02  5.41054225e-03
#  -1.40592456e-01  5.37627339e-02 -4.67863157e-02 -1.82160243e-01
#   1.07414663e-01 -6.42980561e-02 -1.59589037e-01 -2.94056058e-01
#  -2.86766469e-01  6.49541020e-02  2.22044080e-01  1.77445054e-01
#   8.36221695e-01 -1.56608626e-01 -2.02788919e-01 -3.78197758e-03
#   9.39747915e-02 -3.96144688e-01 -7.13487640e-02 -1.34609804e-01
#   6.40799180e-02 -2.49816418e-01 -3.46923828e-01  4.61059250e-02
#   7.07973465e-02 -1.26883723e-02 -2.22583801e-01  6.85411170e-02
#   1.20800093e-01 -1.91582009e-01  1.17266558e-01 -3.25222790e-01
#  -1.79177806e-01  2.43766338e-01  8.66679847e-02 -2.14407127e-02
#  -2.40518406e-01  2.19720140e-01 -1.27385646e-01 -7.89726228e-02
#   1.34947211e-01 -5.96780190e-03 -1.01413038e-02 -8.77440274e-02
#   1.44008929e-02 -8.63934029e-03  1.28788009e-01 -2.93033540e-01
#   1.50608107e-01  9.39852670e-02  3.67037137e-03  8.97667333e-02
#   1.43761620e-01  5.55996634e-02  9.01363790e-02  2.86729145e-03
#  -1.54645428e-01 -1.47357315e-01 -8.80074203e-02 -5.53655684e-01
#   1.06955439e-01  1.82020053e-01  7.28034973e-02 -1.04118511e-01
#   3.18297185e-03  4.86839935e-02 -2.83866916e-02  2.94503480e-01
#  -4.31756265e-02  4.52540815e-01  2.31566116e-01  2.25915238e-01
#  -9.98546034e-02 -4.39825714e-01 -1.26625514e-02  1.15097947e-01
#  -9.21759903e-02  8.60868022e-02 -4.70430255e-02  2.98740566e-01
#   8.25213641e-02 -1.18935905e-01 -3.67475808e-01  6.56639189e-02
#   1.54210553e-01 -1.25227481e-01  2.74649590e-01 -5.33456393e-02
#  -2.17107564e-01 -1.51053309e-01  2.52022266e-01  5.73230386e-02
#  -3.21215577e-02  3.24719220e-01 -7.55839720e-02 -3.61887425e-01
#   1.86695218e-01  3.09910979e-02  5.42746857e-03  1.13803148e-02
#   2.26751983e-01  1.76353082e-01 -8.94468743e-03 -1.46699607e-01
#  -2.00949028e-01  7.89681822e-02  5.55807836e-02  1.95331071e-02
#  -2.97529399e-01 -2.02958167e-01 -1.19158821e-02  1.04395404e-01
#   6.77374527e-02 -2.44218688e-02 -1.23073891e-01  2.48369083e-01
#   4.35770210e-03  1.98270619e-01 -5.19168437e-01 -2.89699346e-01
#  -5.83272465e-02  3.02091062e-01  2.57977217e-01 -1.46803126e-01
#   7.48949721e-02 -1.40918240e-01  8.11334252e-02 -5.30173478e-04
#   3.24561782e-02  2.81632751e-01  1.21698044e-01 -1.32672071e-01
#  -5.52923232e-02  6.84582293e-02  2.38472056e-02 -1.54150665e-01
#   1.36382222e-01  5.55353425e-03  1.15002222e-01  1.28410608e-01
#   2.57016510e-01 -2.30883867e-01 -7.45192543e-02 -2.93642879e-01
#  -4.64630991e-01  2.53557205e-01  4.27564472e-01 -1.99767351e-01
#  -6.93540990e-01 -2.09052190e-01 -4.19376463e-01 -1.93669519e-03
#  -1.13304100e+01 -1.35013297e-01 -2.57835746e-01  2.39985451e-01
#   1.25452317e-03 -6.03495762e-02  1.05068892e-01 -6.46909550e-02
#  -1.14036098e-01 -7.23655149e-02  3.13754737e-01  2.09438801e-01
#   1.94974914e-02 -3.67135741e-02  1.81629360e-01 -9.86699611e-02
#   1.33844186e-03 -1.97601140e-01  1.82101399e-01  1.64726446e-03
#   8.13719407e-02  8.29776898e-02  5.13428114e-02  2.37486407e-01
#   4.27851945e-01 -4.98265177e-02 -5.27669430e-01  1.16912946e-02
#   1.87869862e-01 -2.66181886e-01  2.47824844e-02 -9.96463224e-02
#  -4.16157208e-02  5.73152825e-02  2.52431870e-01 -5.38450889e-02
#   1.44091144e-01  1.04522102e-01  2.47216672e-01  1.51520789e-01
#  -9.11824629e-02 -6.99040294e-02 -1.36787966e-01  1.07741512e-01
#   1.41541541e-01 -1.13980718e-01  5.24107143e-02  1.71523672e-02
#  -3.55568618e-01  2.05546282e-02  7.73332492e-02  1.27147228e-01
#   7.50236288e-02  3.18452597e-01 -2.06100401e-02 -1.50371306e-02
#   1.09332670e-02 -1.06005296e-01  1.75568938e-01 -1.64693538e-02
#  -2.14296137e-03 -1.36956707e-01  4.31889482e-02 -2.13007182e-01
#   3.32549125e-01 -3.68306816e-01 -5.51645197e-02 -2.16331735e-01
#  -5.23908615e-01  5.37193492e-02 -1.94976613e-01 -1.09247006e-01
#   1.29389942e-01 -6.92336440e-01 -6.71287999e-02 -7.55189359e-02
#   1.91214889e-01 -4.39529447e-03 -7.77087882e-02  1.27920553e-01
#  -2.45256275e-01  2.11687192e-01 -6.79868972e-03 -2.04957113e-01
#  -5.66939190e-02  3.46316174e-02 -2.68052042e-01 -4.31403369e-01
#  -1.98024914e-01  1.59157038e-01  1.33546382e-01 -3.56391706e-02
#  -1.89962521e-01  1.21603206e-01 -7.66675873e-03 -1.64178327e-01
#   8.66143033e-02 -2.80560791e-01  8.58099535e-02  1.55569285e-01
#  -1.11602908e-02 -2.76257237e-03  2.11910903e-01 -7.50943571e-02
#  -6.83763549e-02 -2.84467936e-01  3.25929880e-01  1.41704187e-01
#  -6.56097680e-02  5.54894172e-02 -1.45444527e-01  3.71752642e-02
#   3.53834569e-01  8.81586131e-03  1.10959888e-01 -4.08660397e-02
#  -1.26198933e-01  1.51458278e-01  2.40523025e-01 -8.06779414e-03
#  -7.77931586e-02 -7.10876891e-04 -1.59450710e-01 -5.55260070e-02
#  -4.17598672e-02  1.26706794e-01 -1.27542138e-01 -1.11174218e-01
#   7.00956434e-02 -7.36835529e-04  1.90989465e-01  2.72305667e-01
#  -3.53238992e-02  2.28027523e-01 -1.84970796e-01  4.04129893e-01
#   9.01713073e-02 -1.51380062e-01 -1.57911211e-01  3.37371677e-01
#   2.44793370e-01 -2.01235309e-01  7.34792501e-02  6.18184432e-02
#  -1.52977452e-01  1.31872922e-01 -1.16092183e-01  3.19606483e-01
#   7.62388706e-02  1.15962632e-01  1.01117998e-01  4.73666610e-03
#   4.01808601e-03  3.98535579e-02 -9.38015245e-03  1.51629776e-01
#  -2.91865051e-01  2.65773863e-01  1.75994188e-01 -8.24616030e-02
#   2.28149563e-01  1.17342137e-01 -9.84943569e-01 -1.54233389e-02
#   1.33872852e-01  2.04604387e-01 -8.32697675e-02 -2.49107227e-01
#   3.96503478e-01  5.90951666e-02  9.08576772e-02 -5.52822603e-03
#   3.08201045e-01  3.06616396e-01 -2.37562563e-02 -3.89915220e-02
#   9.77943540e-02  1.41439259e-01  1.20916575e-01  3.08824647e-02
#   1.66277811e-01  1.06492214e-01 -7.30718747e-02  4.06108111e-01
#  -3.84190604e-02  1.93150207e-01  3.95198554e-01  1.06966510e-01
#   4.76887286e-01  2.28132173e-01  3.46720032e-02 -1.93362832e-01
#   1.55530632e-01 -1.72088027e-01  1.37680188e-01 -2.39363238e-01
#   4.06662701e-03  1.12017691e-02 -2.09393397e-01  6.07505254e-02
#  -1.49047989e-02 -1.87898368e-01  3.98653001e-02  1.57413885e-01
#  -2.34044448e-01 -1.03680260e-01  1.99059412e-01  2.76504382e-02
#   1.14255652e-01  2.06327677e-01  4.97635752e-02  3.96622628e-01
#   2.70450339e-02  1.18367776e-01  3.53882164e-01  1.02814391e-01
#   1.25516653e-01  1.27773508e-01  4.08599041e-02 -1.16225593e-01
#  -1.34212196e-01  2.36324072e-01 -4.16527055e-02 -3.40314955e-01
#  -2.87582725e-01  1.66915640e-01  9.71457288e-02 -2.15800285e-01
#   1.27249166e-01  3.29844989e-02 -9.26654488e-02 -3.34312499e-01
#   9.05881897e-02  1.75690010e-01  3.15883830e-02  7.05938116e-02
#  -1.31241372e-02  7.01109648e-01 -7.24227428e-02  1.30502358e-01
#  -4.40521270e-01 -2.05619246e-01 -2.89219350e-01 -3.31814364e-02
#  -2.13559456e-02  1.05309635e-01  3.77054252e-02 -3.93090285e-02
#  -2.03359723e-01 -1.09868906e-01  1.94852889e-01  8.05294067e-02
#  -4.09503579e-01  3.24779481e-01  3.18101607e-02  3.63537483e-03
#   8.90817046e-02 -3.54178607e-01 -1.62238866e-01 -1.78459704e-01
#   1.51387036e-01  9.67176706e-02 -2.35614136e-01  3.85565162e-02
#   8.63319263e-02  2.67296076e-01  2.17546150e-01  2.19229266e-01
#   3.43709141e-02  1.90510020e-01  1.86783195e-01 -3.51722211e-01
#   1.56678468e-01  1.32229075e-01 -1.88110337e-01 -3.72735597e-02
#   8.68524145e-03 -1.30599037e-01 -3.28643739e-01 -5.10065891e-02
#   1.28183678e-01 -1.25089744e-02 -1.02274902e-01  4.05600667e-02
#  -4.72651534e-02 -9.59587470e-02  6.98679164e-02  4.61742543e-02
#   1.55388489e-01 -3.56505550e-02  1.03158586e-01  1.92748114e-01
#  -3.24496895e-01 -1.84596390e-01 -6.71282969e-03  2.28605285e-01
#   3.24220359e-02 -6.20960146e-02 -3.86205077e-01  7.23345727e-02
#  -3.94239515e-01  1.32932931e-01 -2.17136353e-01 -4.57042962e-01
#  -1.63512096e-01  2.65161753e-01  1.57784164e-01 -3.01247090e-01
#  -4.48531955e-02  1.01300001e-01  8.15137196e-03  1.97994318e-02
#  -1.77083403e-01  1.41822085e-01  4.15474810e-02  1.60710111e-01
#  -1.88746545e-02  1.98856473e-01  1.87790215e-01 -6.14995323e-03
#  -2.85303891e-02  8.07083398e-02 -3.79004739e-02 -1.51970387e-01
#  -2.02870835e-02  1.28075376e-01  3.61024737e-01  4.01829071e-02
#   1.79790303e-01  5.67579083e-02 -3.15248556e-02 -5.03687523e-02
#   3.90666008e-01  1.43552825e-01 -4.08891998e-02  5.06590046e-02
#  -5.80406822e-02  2.12609470e-01 -1.34122729e-01 -1.37149781e-01
#  -2.95169801e-02  7.98603818e-02  1.52285501e-01 -8.34183097e-02
#   2.54676759e-01  1.41538590e-01  2.34043375e-01 -1.91633813e-02
#  -5.36313280e-02 -3.49930435e-01  4.71805632e-02 -2.61227548e-01
#   2.62641937e-01  6.17272481e-02 -3.31921011e-01 -2.77179092e-01
#   2.21749961e-01 -8.04996789e-02 -2.71337897e-01 -1.06602229e-01
#  -5.68737350e-02  1.74167424e-01 -1.63405817e-02 -9.95147601e-02
#  -7.12312683e-02  1.51727721e-02 -1.81282446e-01 -3.20179760e-02
#   1.54927997e-02 -2.05159583e-03  2.44039759e-01  4.66826707e-01
#  -1.57855719e-01  8.29460993e-02 -2.31699899e-01 -5.82915992e-02
#  -1.60664201e-01  7.93082193e-02 -1.45158276e-01  6.96767941e-02
#  -9.80389044e-02  1.11872107e-01 -3.26825112e-01 -1.37592051e-02
#   1.93446070e-01  1.56935677e-01 -3.78215820e-01  3.14724624e-01
#  -2.13469062e-02  7.38335326e-02 -3.60551151e-03  1.98404584e-02
#  -1.77962422e-01  3.24580997e-01  4.59988713e-02 -2.08667919e-01
#   2.61055470e-01 -8.39513317e-02  3.08468193e-01  1.03311189e-01
#   1.74363628e-01 -2.74168290e-02 -1.16511490e-02 -5.21624228e-03
#   3.10961694e-01  1.38607323e-01 -2.83027828e-01  8.39886069e-02
#  -2.58975886e-02 -6.12243563e-02 -1.86854079e-01 -9.97896269e-02
#  -1.67152509e-02  1.42123193e-01 -1.10992089e-01 -8.23217481e-02
#  -2.12925524e-01 -1.83422044e-02 -9.11637992e-02  5.16224727e-02
#   1.31859139e-01  1.69602558e-02 -1.41550511e-01  1.72561586e-01
#  -6.81758374e-02 -9.82038319e-01 -2.49795884e-01 -7.27391690e-02
#   4.68954518e-02  1.69422507e-01 -1.74359560e-01  4.51800488e-02
#  -2.46497720e-01  1.15618378e-01 -4.27670985e-01 -1.51900098e-01
#  -6.25394732e-02  3.84740084e-02  1.86419725e-01  1.09088393e-02
#   3.32804501e-01  6.05226718e-02 -2.85745025e-01  6.36084899e-02
#  -1.54826373e-01 -8.12577456e-02 -2.25237414e-01 -1.56160071e-01
#  -1.99235290e-01  1.04919694e-01  1.37961730e-01 -2.55925097e-02
#   5.30794226e-02 -3.43935519e-01  1.56873673e-01 -2.47966096e-01
#  -8.62797201e-02  2.04136744e-01  1.36167273e-01 -7.62732401e-02]
